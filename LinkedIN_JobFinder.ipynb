# %% [markdown]
# <a href="https://colab.research.google.com/github/hbakardzhiev/InfoAboutAnyMovie/blob/master/LinkedIN_JobFinder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
title = input("Enter a job title: ")
location = input("Enter a location: ")
start = 0
end = int(input("Enter the number of pages you want to scrap: "))
# Out:
# Enter a job title: HR internship
# Enter a location: Netherlands
# Enter the number of pages you want to scrap: 3

# %%
all_jobs = []
while start < end:
    list_url = f"https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords={title}&location={location}&start={start}"
    response = requests.get(list_url)
    list_data = response.text
    list_soup = BeautifulSoup(list_data, "html.parser")
    page_jobs = list_soup.find_all("li")
    for job in page_jobs:
        all_jobs.append(job)

    start += 1

# %%
user_id = []

# %%
for job in all_jobs:
    base_card_div = job.find("div", {"class": "base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card"})
    job_id = base_card_div.get("data-entity-urn").split(":")[3]
    user_id.append(job_id)

# %%
job = []
for job_id in user_id:
    job_url = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id}"
    job_response = requests.get(job_url)
    job_soup = BeautifulSoup(job_response.text, "html.parser")
    job_post = {}
    try:
        job_post["Job Title"] = job_soup.find("h2", {"class":"top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title"}).text.strip()
    except:
        job_post["Job Title"] = None
    try:
        job_post["Company Name"] = job_soup.find("a", {"class": "topcard__org-name-link topcard__flavor--black-link"}).text.strip()
    except:
        job_post["Company Name"] = None
    try:
        job_post["Location"] = job_soup.find("span", {"class": "topcard__flavor topcard__flavor--bullet"}).text.strip()
    except:
        job_post["Location"] = None
    try:
        job_post["Time Posted"] = job_soup.find("span", {"class": "posted-time-ago__text topcard__flavor--metadata"}).text.strip()
    except:
        job_post["Time Posted"] = None
    try:
        job_post["Num Applicants"] = job_soup.find("figcaption", {"class": "num-applicants__caption"}).text.strip()
    except:
        job_post["Num Applicants"] = None
    job.append(job_post)

# %%
jobs_df = pd.DataFrame(job)
jobs_df
# Out:
#                                        Job Title         Company Name  \
# 0                   Internship - Human Resources             Unilever
# 1                                           None                 None
# 2                                           None                 None
# 3                                           None                 None
# 4                     Human Resources Internship      Gradfuel Europe
# 5                 Human Resource Internship EPDM          Kraft Heinz
# 6                     Human Resources Internship      Gradfuel Europe
# 7                                           None                 None
# 8                          Human Resource Intern  THE ENTOURAGE GROUP
# 9   Internship - Human Resources (Ben & Jerry's)             Unilever
# 10                  Internship - Human Resources             Unilever
# 11                       Intern HR (all genders)           Beiersdorf
# 12                                          None                 None
# 13                    Human Resources Internship      Gradfuel Europe
# 14                                          None                 None
# 15                    Human Resources Internship      Gradfuel Europe
# 16                        Human Resources Intern                  SLB
# 17                         Human Resource Intern  THE ENTOURAGE GROUP
# 18  Internship - Human Resources (Ben & Jerry's)             Unilever
# 19                                     HR Intern       The Social Hub
#
#                                  Location  Time Posted       Num Applicants
# 0     Wageningen, Gelderland, Netherlands  2 weeks ago                 None
# 1                                    None         None                 None
# 2                                    None         None                 None
# 3                                    None         None                 None
# 4   Amsterdam, North Holland, Netherlands  2 weeks ago                 None
# 5   Amsterdam, North Holland, Netherlands  2 weeks ago                 None
# 6   Amsterdam, North Holland, Netherlands  2 weeks ago                 None
# 7                                    None         None                 None
# 8   Amsterdam, North Holland, Netherlands  2 weeks ago                 None
# 9    Hellendoorn, Overijssel, Netherlands  3 weeks ago                 None
# 10  Rotterdam, South Holland, Netherlands  2 weeks ago  Over 200 applicants
# 11  Amsterdam, North Holland, Netherlands   1 week ago                 None
# 12                                   None         None                 None
# 13  Amsterdam, North Holland, Netherlands  2 weeks ago                 None
# 14                                   None         None                 None
# 15  Amsterdam, North Holland, Netherlands  2 weeks ago                 None
# 16  The Hague, South Holland, Netherlands   1 week ago                 None
# 17  Amsterdam, North Holland, Netherlands  2 weeks ago                 None
# 18   Hellendoorn, Overijssel, Netherlands  3 weeks ago                 None
# 19  Amsterdam, North Holland, Netherlands  2 weeks ago                 None
